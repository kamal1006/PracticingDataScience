# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("train_ctrUa4K.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ## Data Preparation

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
100*df.isnull().sum()/len(df.index)
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df1=df[~np.isnan(df.Credit_History)]

# %%
100*df1.isnull().sum()/len(df1.index)
# Out:
# Loan_ID              0.000000
# Gender               2.127660
# Married              0.531915
# Dependents           2.659574
# Education            0.000000
# Self_Employed        4.609929
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.723404
# Loan_Amount_Term     2.482270
# Credit_History       0.000000
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df2=df1[~pd.isnull(df1.Self_Employed)]

# %%
100*df2.isnull().sum()/len(df2.index)
# Out:
# Loan_ID              0.000000
# Gender               2.230483
# Married              0.557621
# Dependents           2.788104
# Education            0.000000
# Self_Employed        0.000000
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.903346
# Loan_Amount_Term     2.416357
# Credit_History       0.000000
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df2=df2[~np.isnan(df2.LoanAmount)]

# %%
df2=df2[~np.isnan(df2.Loan_Amount_Term)]

# %%
100*df2.isnull().sum()/len(df2.index)
# Out:
# Loan_ID              0.000000
# Gender               2.380952
# Married              0.396825
# Dependents           2.380952
# Education            0.000000
# Self_Employed        0.000000
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           0.000000
# Loan_Amount_Term     0.000000
# Credit_History       0.000000
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df3=df2[~df2.Gender.isnull()]

# %%
100*df3.isnull().sum()/len(df3.index)
# Out:
# Loan_ID              0.000000
# Gender               0.000000
# Married              0.406504
# Dependents           2.439024
# Education            0.000000
# Self_Employed        0.000000
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           0.000000
# Loan_Amount_Term     0.000000
# Credit_History       0.000000
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df4=df3[~df3.Dependents.isnull()]

# %%
100*df4.isnull().sum()/len(df4.index)
# Out:
# Loan_ID              0.0
# Gender               0.0
# Married              0.0
# Dependents           0.0
# Education            0.0
# Self_Employed        0.0
# ApplicantIncome      0.0
# CoapplicantIncome    0.0
# LoanAmount           0.0
# Loan_Amount_Term     0.0
# Credit_History       0.0
# Property_Area        0.0
# Loan_Status          0.0
# dtype: float64

# %%
len(df4)
# Out:
# 480

# %%
len(df)
# Out:
# 614

# %%
df4.Dependents.value_counts()
# Out:
# 0     274
# 2      85
# 1      80
# 3+     41
# Name: Dependents, dtype: int64

# %%
df4.Education.value_counts()
# Out:
# Graduate        383
# Not Graduate     97
# Name: Education, dtype: int64

# %%
#    Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#  '  Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
 # 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'

# %%
df4.Gender=df4.Gender.apply(lambda x:1 if x=="Male" else 0)
df4.Married=df4.Married.apply(lambda x:1 if x=="Yes" else 0)
df4.Education=df4.Education.apply(lambda x:1 if x=="Graduate" else 0)
df4.Self_Employed=df4.Self_Employed.apply(lambda x:1 if x=="Yes" else 0)
df4.Property_Area=df4.Property_Area.apply(lambda x:1 if x=="Urban" else 0)
df4.Loan_Status=df4.Loan_Status.apply(lambda x:1 if x=="Y" else 0)

# %%
df4.Gender.value_counts()
# Out:
# 1    394
# 0     86
# Name: Gender, dtype: int64

# %%
df4.Loan_Status.value_counts()
# Out:
# 1    332
# 0    148
# Name: Loan_Status, dtype: int64

# %%
df4
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1    LP001003       1        1          1          1              0
# 2    LP001005       1        1          0          1              1
# 3    LP001006       1        1          0          0              0
# 4    LP001008       1        0          0          1              0
# 5    LP001011       1        1          2          1              1
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          1              0
# 610  LP002979       1        1         3+          1              0
# 611  LP002983       1        1          1          1              0
# 612  LP002984       1        1          2          1              0
# 613  LP002990       0        0          0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
df4
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1    LP001003       1        1          1          1              0
# 2    LP001005       1        1          0          1              1
# 3    LP001006       1        1          0          0              0
# 4    LP001008       1        0          0          1              0
# 5    LP001011       1        1          2          1              1
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          1              0
# 610  LP002979       1        1         3+          1              0
# 611  LP002983       1        1          1          1              0
# 612  LP002984       1        1          2          1              0
# 613  LP002990       0        0          0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
## creating dummies for dependents

dum1=pd.get_dummies(df4.Dependents, prefix="dep", drop_first=True)
dum1
df4=df4.drop(['Dependents'],1)
df4=pd.concat([df4,dum1],axis=1)

# %%
df4
# Out:
#       Loan_ID  Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 1    LP001003       1        1          1              0             4583
# 2    LP001005       1        1          1              1             3000
# 3    LP001006       1        1          0              0             2583
# 4    LP001008       1        0          1              0             6000
# 5    LP001011       1        1          1              1             5417
# ..        ...     ...      ...        ...            ...              ...
# 609  LP002978       0        0          1              0             2900
# 610  LP002979       1        1          1              0             4106
# 611  LP002983       1        1          1              0             8072
# 612  LP002984       1        1          1              0             7583
# 613  LP002990       0        0          1              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            480 non-null    object
#  1   Gender             480 non-null    int64
#  2   Married            480 non-null    int64
#  3   Education          480 non-null    int64
#  4   Self_Employed      480 non-null    int64
#  5   ApplicantIncome    480 non-null    int64
#  6   CoapplicantIncome  480 non-null    float64
#  7   LoanAmount         480 non-null    float64
#  8   Loan_Amount_Term   480 non-null    float64
#  9   Credit_History     480 non-null    float64
#  10  Property_Area      480 non-null    int64
#  11  Loan_Status        480 non-null    int64
#  12  dep_1              480 non-null    uint8
#  13  dep_2              480 non-null    uint8
#  14  dep_3+             480 non-null    uint8
# dtypes: float64(4), int64(7), object(1), uint8(3)
# ...

# %% [markdown]
# ## Feature Scaling for numerical vars

# %%
num=['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
df4[num]=scaler.fit_transform(df4[num])
df4.head()
# Out:
#     Loan_ID  Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 1  LP001003       1        1          1              0        -0.137970
# 2  LP001005       1        1          1              1        -0.417536
# 3  LP001006       1        1          0              0        -0.491180
# 4  LP001008       1        0          1              0         0.112280
# 5  LP001011       1        1          1              1         0.009319
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1          -0.027952   -0.208089          0.275542             1.0
# 2          -0.604633   -0.979001          0.275542             1.0
# 3           0.297100   -0.307562          0.275542             1.0
# 4          -0.604633   -0.046446          0.275542             1.0
# 5           0.999978    1.520245          0.275542             1.0
#
#    Property_Area  Loan_Status  dep_1  dep_2  dep_3+
# 1              0            0      1      0       0
# ...

# %%
# looking for corerelations


import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df4.corr(),annot=True)
plt.show()

# %%
df4.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'dep_1', 'dep_2', 'dep_3+'],
#       dtype='object')

# %%
X_train=df4[['Gender', 'Married', 'Education', 'Self_Employed','ApplicantIncome', 'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term', 'Credit_History', 'Property_Area','Loan_Status','dep_1', 'dep_2','dep_3+']]

# %%
y_train=X_train.pop('Loan_Status')

# %%
y_train
# Out:
# 1      0
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 480, dtype: int64

# %%
X_train
# Out:
#      Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 1         1        1          1              0        -0.137970
# 2         1        1          1              1        -0.417536
# 3         1        1          0              0        -0.491180
# 4         1        0          1              0         0.112280
# 5         1        1          1              1         0.009319
# ..      ...      ...        ...            ...              ...
# 609       0        0          1              0        -0.435196
# 610       1        1          1              0        -0.222210
# 611       1        1          1              0         0.478206
# 612       1        1          1              0         0.391846
# 613       0        0          1              1        -0.137970
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1            -0.027952   -0.208089          0.275542             1.0
# ...

# %%
#loan amount vs applicant income

# %% [markdown]
# # Model Building

# %%
import statsmodels.api as sm

# %%
logm1=sm.GLM(y_train,(sm.add_constant(X_train)), family=sm.families.Binomial())
logm1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            Loan_Status   No. Observations:                  480
# Model:                            GLM   Df Residuals:                      466
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -223.30
# Date:                Sun, 07 Mar 2021   Deviance:                       446.61
# Time:                        16:02:26   Pearson chi2:                     483.
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()

# %%
from sklearn.feature_selection import RFE
rfe=RFE(logreg,10)
rfe=rfe.fit(X_train,y_train)

# %%
rfe.support_
# Out:
# array([ True,  True,  True,  True, False,  True,  True, False,  True,
#         True,  True,  True, False])

# %%
list(zip(X_train,rfe.support_,rfe.ranking_))
# Out:
# [('Gender', True, 1),
#  ('Married', True, 1),
#  ('Education', True, 1),
#  ('Self_Employed', True, 1),
#  ('ApplicantIncome', False, 4),
#  ('CoapplicantIncome', True, 1),
#  ('LoanAmount', True, 1),
#  ('Loan_Amount_Term', False, 3),
#  ('Credit_History', True, 1),
#  ('Property_Area', True, 1),
#  ('dep_1', True, 1),
#  ('dep_2', True, 1),
#  ('dep_3+', False, 2)]

# %%
col=X_train.columns[rfe.support_]

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['ApplicantIncome', 'Loan_Amount_Term', 'dep_3+'], dtype='object')

# %%
col
# Out:
# Index(['Gender', 'Married', 'Education', 'Self_Employed', 'CoapplicantIncome',
#        'LoanAmount', 'Credit_History', 'Property_Area', 'dep_1', 'dep_2'],
#       dtype='object')

# %%
X_train=sm.add_constant(X_train[col])
logm2=sm.GLM(y_train,X_train,family=sm.families.Binomial())
res=logm2.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            Loan_Status   No. Observations:                  480
# Model:                            GLM   Df Residuals:                      469
# Model Family:                Binomial   Df Model:                           10
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -223.57
# Date:                Sun, 07 Mar 2021   Deviance:                       447.14
# Time:                        16:02:26   Pearson chi2:                     487.
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
y_train_pred=res.predict(X_train)
y_train_pred[:10]
# Out:
# 1     0.840465
# 2     0.842657
# 3     0.749875
# 4     0.724360
# 5     0.755159
# 6     0.770566
# 7     0.146992
# 8     0.844858
# 9     0.635328
# 10    0.882263
# dtype: float64

# %%
y_train_pred=y_train_pred.values.reshape(-1)
y_train_pred[:10]
# Out:
# array([0.84046529, 0.84265658, 0.74987474, 0.72435965, 0.75515925,
#        0.7705656 , 0.14699196, 0.84485796, 0.63532781, 0.8822628 ])

# %%
y_train_pred_final=pd.DataFrame({'Loan':y_train.values,'Loan_prob':y_train_pred,'Load_ID':df4['Loan_ID']})
y_train_pred_final
# Out:
#      Loan  Loan_prob   Load_ID
# 1       0   0.840465  LP001003
# 2       1   0.842657  LP001005
# 3       1   0.749875  LP001006
# 4       1   0.724360  LP001008
# 5       1   0.755159  LP001011
# ..    ...        ...       ...
# 609     1   0.784625  LP002978
# 610     1   0.906824  LP002979
# 611     1   0.731359  LP002983
# 612     1   0.847970  LP002984
# 613     0   0.068638  LP002990
#
# [480 rows x 3 columns]

# %%
# creatinmg new column 

y_train_pred_final['predict']=y_train_pred_final.Loan_prob.map(lambda x:1 if x>0.5 else 0)
y_train_pred_final
# Out:
#      Loan  Loan_prob   Load_ID  predict
# 1       0   0.840465  LP001003        1
# 2       1   0.842657  LP001005        1
# 3       1   0.749875  LP001006        1
# 4       1   0.724360  LP001008        1
# 5       1   0.755159  LP001011        1
# ..    ...        ...       ...      ...
# 609     1   0.784625  LP002978        1
# 610     1   0.906824  LP002979        1
# 611     1   0.731359  LP002983        1
# 612     1   0.847970  LP002984        1
# 613     0   0.068638  LP002990        0
#
# [480 rows x 4 columns]

# %%
from sklearn import metrics

# %%
confusion= metrics.confusion_matrix(y_train_pred_final.Loan,y_train_pred_final.predict)
confusion
# Out:
# array([[ 64,  84],
#        [  7, 325]], dtype=int64)

# %%
print(metrics.accuracy_score(y_train_pred_final.Loan,y_train_pred_final.predict))
# Out:
# 0.8104166666666667

# %%
# checking VIF

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['features']=X_train[col].columns
vif['VIF']=[variance_inflation_factor(X_train[col].values,i) for i in range(X_train[col].shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#             features   VIF
# 0             Gender  5.11
# 6     Credit_History  4.86
# 2          Education  3.88
# 1            Married  3.59
# 7      Property_Area  1.49
# 9              dep_2  1.42
# 8              dep_1  1.36
# 3      Self_Employed  1.17
# 5         LoanAmount  1.12
# 4  CoapplicantIncome  1.05

# %%
col=col.drop('Gender')
col
# Out:
# Index(['Married', 'Education', 'Self_Employed', 'CoapplicantIncome',
#        'LoanAmount', 'Credit_History', 'Property_Area', 'dep_1', 'dep_2'],
#       dtype='object')

# %%
X_train=sm.add_constant(X_train[col])
logm2=sm.GLM(y_train,X_train,family=sm.families.Binomial())
res=logm2.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            Loan_Status   No. Observations:                  480
# Model:                            GLM   Df Residuals:                      470
# Model Family:                Binomial   Df Model:                            9
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -223.85
# Date:                Sun, 07 Mar 2021   Deviance:                       447.70
# Time:                        16:02:26   Pearson chi2:                     488.
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
vif=pd.DataFrame()
vif['features']=X_train[col].columns
vif['VIF']=[variance_inflation_factor(X_train[col].values,i) for i in range(X_train[col].shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#             features   VIF
# 5     Credit_History  4.17
# 1          Education  3.71
# 0            Married  2.92
# 6      Property_Area  1.47
# 8              dep_2  1.42
# 7              dep_1  1.35
# 2      Self_Employed  1.17
# 4         LoanAmount  1.12
# 3  CoapplicantIncome  1.05

# %%
col=col.drop('Self_Employed')
col
# Out:
# Index(['Married', 'Education', 'CoapplicantIncome', 'LoanAmount',
#        'Credit_History', 'Property_Area', 'dep_1', 'dep_2'],
#       dtype='object')

# %%
X_train=sm.add_constant(X_train[col])
logm2=sm.GLM(y_train,X_train,family=sm.families.Binomial())
res=logm2.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            Loan_Status   No. Observations:                  480
# Model:                            GLM   Df Residuals:                      471
# Model Family:                Binomial   Df Model:                            8
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -223.95
# Date:                Sun, 07 Mar 2021   Deviance:                       447.91
# Time:                        16:02:26   Pearson chi2:                     489.
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
vif=pd.DataFrame()
vif['features']=X_train[col].columns
vif['VIF']=[variance_inflation_factor(X_train[col].values,i) for i in range(X_train[col].shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#             features   VIF
# 4     Credit_History  4.14
# 1          Education  3.70
# 0            Married  2.92
# 5      Property_Area  1.47
# 7              dep_2  1.41
# 6              dep_1  1.34
# 3         LoanAmount  1.11
# 2  CoapplicantIncome  1.05

# %%
col=col.drop('dep_2')
col
# Out:
# Index(['Married', 'Education', 'CoapplicantIncome', 'LoanAmount',
#        'Credit_History', 'Property_Area', 'dep_1'],
#       dtype='object')

# %%
X_train=sm.add_constant(X_train[col])
logm2=sm.GLM(y_train,X_train,family=sm.families.Binomial())
res=logm2.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            Loan_Status   No. Observations:                  480
# Model:                            GLM   Df Residuals:                      472
# Model Family:                Binomial   Df Model:                            7
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -224.15
# Date:                Sun, 07 Mar 2021   Deviance:                       448.30
# Time:                        16:02:26   Pearson chi2:                     490.
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
vif=pd.DataFrame()
vif['features']=X_train[col].columns
vif['VIF']=[variance_inflation_factor(X_train[col].values,i) for i in range(X_train[col].shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#             features   VIF
# 4     Credit_History  4.12
# 1          Education  3.70
# 0            Married  2.62
# 5      Property_Area  1.45
# 6              dep_1  1.25
# 3         LoanAmount  1.11
# 2  CoapplicantIncome  1.05

# %%
col=col.drop('CoapplicantIncome')
col
# Out:
# Index(['Married', 'Education', 'LoanAmount', 'Credit_History', 'Property_Area',
#        'dep_1'],
#       dtype='object')

# %%
X_train=sm.add_constant(X_train[col])
logm2=sm.GLM(y_train,X_train,family=sm.families.Binomial())
res=logm2.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            Loan_Status   No. Observations:                  480
# Model:                            GLM   Df Residuals:                      473
# Model Family:                Binomial   Df Model:                            6
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -224.79
# Date:                Sun, 07 Mar 2021   Deviance:                       449.57
# Time:                        16:02:26   Pearson chi2:                     488.
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
vif=pd.DataFrame()
vif['features']=X_train[col].columns
vif['VIF']=[variance_inflation_factor(X_train[col].values,i) for i in range(X_train[col].shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#          features   VIF
# 3  Credit_History  4.11
# 1       Education  3.70
# 0         Married  2.61
# 4   Property_Area  1.45
# 5           dep_1  1.24
# 2      LoanAmount  1.08

# %%
col=col.drop('dep_1')
col
# Out:
# Index(['Married', 'Education', 'LoanAmount', 'Credit_History',
#        'Property_Area'],
#       dtype='object')

# %%
X_train=sm.add_constant(X_train[col])
logm2=sm.GLM(y_train,X_train,family=sm.families.Binomial())
res=logm2.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            Loan_Status   No. Observations:                  480
# Model:                            GLM   Df Residuals:                      474
# Model Family:                Binomial   Df Model:                            5
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -225.42
# Date:                Sun, 07 Mar 2021   Deviance:                       450.83
# Time:                        16:02:27   Pearson chi2:                     490.
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
vif=pd.DataFrame()
vif['features']=X_train[col].columns
vif['VIF']=[variance_inflation_factor(X_train[col].values,i) for i in range(X_train[col].shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#          features   VIF
# 3  Credit_History  4.10
# 1       Education  3.69
# 0         Married  2.54
# 4   Property_Area  1.43
# 2      LoanAmount  1.07

# %%
y_train_pred=res.predict(X_train)
y_train_pred[:10]
y_train_pred=y_train_pred.values.reshape(-1)
y_train_pred[:10]
y_train_pred_final=pd.DataFrame({'Loan':y_train.values,'Loan_prob':y_train_pred,'Load_ID':df4['Loan_ID']})
y_train_pred_final
y_train_pred_final['predict']=y_train_pred_final.Loan_prob.map(lambda x:1 if x>0.59 else 0)
y_train_pred_final
confusion= metrics.confusion_matrix(y_train_pred_final.Loan,y_train_pred_final.predict)
confusion
print(metrics.accuracy_score(y_train_pred_final.Loan,y_train_pred_final.predict))
# Out:
# 0.8125

# %%
tf=pd.read_csv("test_lAUu6dG.csv")

# %%
tf
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
tf.Gender=tf.Gender.apply(lambda x:1 if x=="Male" else 0)
tf.Married=tf.Married.apply(lambda x:1 if x=="Yes" else 0)
tf.Education=tf.Education.apply(lambda x:1 if x=="Graduate" else 0)
tf.Self_Employed=tf.Self_Employed.apply(lambda x:1 if x=="Yes" else 0)
tf.Property_Area=tf.Property_Area.apply(lambda x:1 if x=="Urban" else 0)

# %%
tf
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001015       1        1          0          1              0
# 1    LP001022       1        1          1          1              0
# 2    LP001031       1        1          2          1              0
# 3    LP001035       1        1          2          1              0
# 4    LP001051       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1         3+          0              1
# 363  LP002975       1        1          0          1              0
# 364  LP002980       1        0          0          1              0
# 365  LP002986       1        1          0          1              0
# 366  LP002989       1        0          0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
tf[num]=scaler.fit_transform(tf[num])

# %%
tf
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001015       1        1          0          1              0
# 1    LP001022       1        1          1          1              0
# 2    LP001031       1        1          2          1              0
# 3    LP001035       1        1          2          1              0
# 4    LP001051       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1         3+          0              1
# 363  LP002975       1        1          0          1              0
# 364  LP002980       1        0          0          1              0
# 365  LP002986       1        1          0          1              0
# 366  LP002989       1        0          0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.186461          -0.673335   -0.426433          0.268382
# ...

# %%
tf3=tf[['Credit_History','Education','Married','Property_Area','LoanAmount']]
tf3
# Out:
#      Credit_History  Education  Married  Property_Area  LoanAmount
# 0               1.0          1        1              1   -0.426433
# 1               1.0          1        1              1   -0.165344
# 2               1.0          1        1              1    1.172736
# 3               NaN          1        1              1   -0.589614
# 4               1.0          0        0              1   -0.948611
# ..              ...        ...      ...            ...         ...
# 362             1.0          0        1              1   -0.377479
# 363             1.0          1        1              1   -0.344843
# 364             NaN          1        0              0   -0.165344
# 365             1.0          1        1              0    0.356833
# 366             1.0          1        0              0   -0.622250
#
# [367 rows x 5 columns]

# %%
X_test=tf3

# %%
X_test=sm.add_constant(X_test)

# %%
y_test_pred = res.predict(X_test)

# %%
y_test_pred
# Out:
# 0      0.850341
# 1      0.837382
# 2      0.756686
# 3           NaN
# 4      0.853720
#          ...
# 362    0.784450
# 363    0.846385
# 364         NaN
# 365    0.107188
# 366    0.183359
# Length: 367, dtype: float64

# %%
y_test_pred = y_test_pred.values.reshape(-1)

# %%
y_test_pred_final=pd.DataFrame({"load ID":tf['Loan_ID'],"Prop":y_test_pred})

# %%
y_test_pred_final
# Out:
#       load ID      Prop
# 0    LP001015  0.850341
# 1    LP001022  0.837382
# 2    LP001031  0.756686
# 3    LP001035       NaN
# 4    LP001051  0.853720
# ..        ...       ...
# 362  LP002971  0.784450
# 363  LP002975  0.846385
# 364  LP002980       NaN
# 365  LP002986  0.107188
# 366  LP002989  0.183359
#
# [367 rows x 2 columns]

# %%
y_test_pred_final['Prop']=y_test_pred_final['Prop'].apply(lambda x:"Y" if x>0.59 else "N")

# %%
y_test_pred_final
# Out:
#       load ID Prop
# 0    LP001015    Y
# 1    LP001022    Y
# 2    LP001031    Y
# 3    LP001035    N
# 4    LP001051    Y
# ..        ...  ...
# 362  LP002971    Y
# 363  LP002975    Y
# 364  LP002980    N
# 365  LP002986    N
# 366  LP002989    N
#
# [367 rows x 2 columns]

# %%
y_test_pred_final['Prop'].value_counts()
# Out:
# N    242
# Y    125
# Name: Prop, dtype: int64

# %%
y_test_pred_final.to_csv('Kamal_submission.csv', index=False)
